# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread('C:/Users/91976/OneDrive/Desktop/Rose.jpg')

# %%
img
# Out:
# array([[[ 6,  8,  3],
#         [ 4,  6,  1],
#         [ 4,  6,  1],
#         ...,
#         [ 5,  5,  3],
#         [ 6,  6,  4],
#         [ 7,  7,  5]],
#
#        [[ 5,  7,  2],
#         [ 4,  6,  1],
#         [ 6,  8,  3],
#         ...,
#         [ 3,  3,  1],
#         [ 5,  5,  3],
#         [ 7,  7,  5]],
#
#        [[ 5,  7,  2],
#         [ 4,  6,  1],
#         [ 6,  8,  3],
#         ...,
#         [ 2,  2,  0],
#         [ 3,  3,  1],
#         [ 6,  6,  4]],
#
#        ...,
#
#        [[ 5, 11,  1],
#         [ 6, 12,  2],
#         [ 7, 13,  3],
#         ...,
#         [ 5,  5,  3],
#         [ 7,  7,  5],
#         [ 9,  9,  7]],
#
#        [[10, 16,  6],
#         [10, 16,  6],
#         [10, 16,  6],
#         ...,
#         [ 5,  5,  3],
#         [ 5,  5,  3],
#         [ 6,  6,  4]],
#
#        [[10, 16,  6],
#         [10, 16,  6],
#         [10, 16,  6],
#         ...,
#         [ 5,  5,  3],
#         [ 5,  5,  3],
#         [ 6,  6,  4]]], dtype=uint8)

# %%
img.max()
# Out:
# 255

# %%
img.min()
# Out:
# 0

# %%
img.shape
# Out:
# (3466, 3144, 3)

# %%
plt.imshow(img)

# %%
img_scaled = img/255.0

# %%
img_scaled
# Out:
# array([[[0.02352941, 0.03137255, 0.01176471],
#         [0.01568627, 0.02352941, 0.00392157],
#         [0.01568627, 0.02352941, 0.00392157],
#         ...,
#         [0.01960784, 0.01960784, 0.01176471],
#         [0.02352941, 0.02352941, 0.01568627],
#         [0.02745098, 0.02745098, 0.01960784]],
#
#        [[0.01960784, 0.02745098, 0.00784314],
#         [0.01568627, 0.02352941, 0.00392157],
#         [0.02352941, 0.03137255, 0.01176471],
#         ...,
#         [0.01176471, 0.01176471, 0.00392157],
#         [0.01960784, 0.01960784, 0.01176471],
#         [0.02745098, 0.02745098, 0.01960784]],
#
#        [[0.01960784, 0.02745098, 0.00784314],
#         [0.01568627, 0.02352941, 0.00392157],
#         [0.02352941, 0.03137255, 0.01176471],
#         ...,
#         [0.00784314, 0.00784314, 0.        ],
#         [0.01176471, 0.01176471, 0.00392157],
#         [0.02352941, 0.02352941, 0.01568627]],
#
#        ...,
#
#        [[0.01960784, 0.04313725, 0.00392157],
# ...

# %%
img_scaled.max()
# Out:
# 1.0

# %%
img_scaled.min()
# Out:
# 0.0

# %%
plt.imshow(img) # image is not disturbed here, just we rescaled the image
